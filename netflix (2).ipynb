# %% [markdown]
# # ****NETFLIX ANALYSIS****

# %% [markdown]
# ## Problem statement
#  with the rapid expansion of digital streaming platforms.Netflix has developed a vaste librery of movies and tv shows across different countries types and durations.hoever, understanding the pateerns within this large dataset is essential to identify trends in content production.Audiance targeting and platform groth
#  The project aims to analyse the Netflix dataset to explore the distribution and charecterestics of content available on the platform.The study focuses on identifying patterns in content type(movies vs Tvshows).Release trends over the years,country-wise contributions,rating classification,and duration

# %% [markdown]
# ## About the data set
# - The dataset used in this project is the Netflix  Dataset and it contains information about movies and TV shows on Netflix.
# - There are about 8,807 records in the dataset.
# - It includes details like title, type, director, cast, country, release year, rating, duration, and genre Some data was missing, so it has to be cleaned.
# - The duration column was also corrected.Movies are measured in minutes, and TV shows are measured in seasons.
# - This dataset helps us understand Netflix content, such as popular genres, release trends, and audience types. It is useful for learning data analysis.

# %% [markdown]
# ## Aim of the Project
# The aim of this project is to understand Netflix content. It helps to analyze movies and TV shows, find popular genres, study release year trends, and understand audience ratings. It is mainly used to learn data analysis and visualization.

# %% [markdown]
#  ## Importing libraries

# %%
import pandas as pd   #data hndling
import matplotlib.pyplot as plt  #visualisation
import seaborn as sns     #visualisation

# %% [markdown]
# ## Loading data set

# %%
df=pd.read_csv("netflixx.csv")
print(df)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# ## Inspect data

# %%
df.head(8)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 2                                                NaN  September 24, 2021
# 3                                                NaN  September 24, 2021
# 4                                              India  September 24, 2021
# 5                                                NaN  September 24, 2021
# 6                                                NaN  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...

# %%
df.tail(6)
# Out:
#      show_id     type        title         director  \
# 8801   s8802    Movie      Zinzana  Majid Al Ansari
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast  \
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                            country         date_added  release_year rating  \
# 8801  United Arab Emirates, Jordan      March 9, 2016          2015  TV-MA
# 8802                 United States  November 20, 2019          2007      R
# 8803                           NaN       July 1, 2019          2018  TV-Y7
# 8804                 United States   November 1, 2019          2009      R
# 8805                 United States   January 11, 2020          2006     PG
# 8806                         India      March 2, 2019          2015  TV-14
#
#        duration                                       listed_in  \
# 8801     96 min         Dramas, International Movies, Thrillers
# 8802    158 min                  Cult Movies, Dramas, Thrillers
# 8803  2 Seasons          Kids' TV, Korean TV Shows, TV Comedies
# 8804     88 min                         Comedies, Horror Movies
# 8805     88 min              Children & Family Movies, Comedies
# 8806    111 min  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8801  Recovering alcoholic Talal wakes up inside a s...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
df.sample(3)
# Out:
#      show_id     type                                      title  \
# 3772   s3773    Movie                              Alles ist gut
# 2795   s2796  TV Show     Tiger King: Murder, Mayhem and Madness
# 6927   s6928    Movie  Harold & Kumar Escape from Guantanamo Bay
#
#                              director  \
# 3772                     Eva Trobisch
# 2795     Eric Goode, Rebecca Chaiklin
# 6927  Jon Hurwitz, Hayden Schlossberg
#
#                                                    cast        country  \
# 3772  Aenne Schwarz, Andreas Döhler, Hans Löw, Tilo ...        Germany
# 2795                                                NaN  United States
# 6927  John Cho, Kal Penn, Rob Corddry, Jack Conley, ...  United States
#
#            date_added  release_year rating  duration  \
# 3772     June 6, 2019          2019  TV-MA    90 min
# 2795   March 20, 2020          2020  TV-MA  1 Season
# 6927  October 1, 2019          2008      R   101 min
#
#                          listed_in  \
# 3772  Dramas, International Movies
# 2795    Crime TV Shows, Docuseries
# 6927         Comedies, Cult Movies
#
#                                             description
# 3772  A woman sexually assaulted by her new boss's b...
# 2795  A zoo owner spirals out of control amid a cast...
# 6927  Harold and Kumar jump on a plane to catch up w...

# %% [markdown]
# ## check column data type

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ## Display column names

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ## display no.of rows and columns

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# - total 12 columns
# - memory usage:825.8+kb
# - missing values(director)=2634
# - missing values(country):831
# - missing values (data_adeed):10
# - missing values(eating):4
# - missing values(duration):3
# - data type mistake(duration):duration is not oject,it is int64

# %% [markdown]
# ## selecting columns

# %%
df["type"]
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %%
df["duration"]
# Out:
# 0          90 min
# 1       2 Seasons
# 2        1 Season
# 3        1 Season
# 4       2 Seasons
#           ...
# 8802      158 min
# 8803    2 Seasons
# 8804       88 min
# 8805       88 min
# 8806      111 min
# Name: duration, Length: 8807, dtype: object

# %%
df["director"]
# Out:
# 0       Kirsten Johnson
# 1                   NaN
# 2       Julien Leclercq
# 3                   NaN
# 4                   NaN
#              ...
# 8802      David Fincher
# 8803                NaN
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
df["cast"]
# Out:
# 0                                                     NaN
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                     NaN
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                  NaN
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8807, dtype: object

# %% [markdown]
# ## selecting multiple columns

# %%
df[["type","country"]]
# Out:
#          type        country
# 0       Movie  United States
# 1     TV Show   South Africa
# 2     TV Show            NaN
# 3     TV Show            NaN
# 4     TV Show          India
# ...       ...            ...
# 8802    Movie  United States
# 8803  TV Show            NaN
# 8804    Movie  United States
# 8805    Movie  United States
# 8806    Movie          India
#
# [8807 rows x 2 columns]

# %%
new=df[["country","cast"]]

# %%
new
# Out:
#             country                                               cast
# 0     United States                                                NaN
# 1      South Africa  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2               NaN  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3               NaN                                                NaN
# 4             India  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...             ...                                                ...
# 8802  United States  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803            NaN                                                NaN
# 8804  United States  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  United States  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806          India  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
# [8807 rows x 2 columns]

# %% [markdown]
# ## filter the data

# %%
df[df['release_year']<2000]
# Out:
#      show_id   type                                title          director  \
# 7         s8  Movie                              Sankofa      Haile Gerima
# 22       s23  Movie                      Avvai Shanmughi    K.S. Ravikumar
# 24       s25  Movie                                Jeans        S. Shankar
# 26       s27  Movie                       Minsara Kanavu       Rajiv Menon
# 41       s42  Movie                                 Jaws  Steven Spielberg
# ...      ...    ...                                  ...               ...
# 8745   s8746  Movie  Willy Wonka & the Chocolate Factory        Mel Stuart
# 8748   s8749  Movie                 Winter of Our Dreams       John Duigan
# 8763   s8764  Movie      WWII: Report from the Aleutians       John Huston
# 8764   s8765  Movie                           Wyatt Earp   Lawrence Kasdan
# 8792   s8793  Movie                          Young Tiger            Mu Chu
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 26    Arvind Swamy, Kajol, Prabhu Deva, Nassar, S.P....
# 41    Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
#

# 8802  A political cartoonist, a crime reporter and a...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
#
# [2818 rows x 12 columns]

# %%
df[df["director"]=="Mu Chu"]
# Out:
#      show_id   type        title director  \
# 8792   s8793  Movie  Young Tiger   Mu Chu
#
#                                                    cast    country  \
# 8792  Qiu Yuen, Charlie Chin, Jackie Chan, Hu Chin, ...  Hong Kong
#
#             date_added  release_year rating duration  \
# 8792  November 1, 2016          1973     NR   81 min
#
#                                      listed_in  \
# 8792  Action & Adventure, International Movies
#
#                                             description
# 8792  Aided only by a tough female police officer, a...

# %% [markdown]
# ## multiple filter

# %%
df[(df["country"]=="India")&(df["release_year"]<2000)]
# Out:
#      show_id   type                           title         director  \
# 24       s25  Movie                           Jeans       S. Shankar
# 114     s115  Movie                          Anjaam     Rahul Rawail
# 253     s254  Movie                          Bombay      Mani Ratnam
# 542     s543  Movie                           Ujala    Naresh Saigal
# 1441   s1442  Movie                   Hello Brother      Sohail Khan
# ...      ...    ...                             ...              ...
# 8136   s8137  Movie                           Swami  Basu Chatterjee
# 8144   s8145  Movie                            Taal     Subhash Ghai
# 8332   s8333  Movie               The Great Gambler   Shakti Samanta
# 8628   s8629  Movie  Trikal (Past, Present, Future)    Shyam Benegal
# 8629   s8630  Movie                        Trimurti      Mukul Anand
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# 114   Madhuri Dixit, Shah Rukh Khan, Tinnu Anand, Jo...   India
# 253   Arvind Swamy, Manisha Koirala, Nasser, Raja Kr...   India
# 542   Mala Sinha, Shammi Kapoor, Raaj Kumar, Leela C...   India
# 1441  Salman Khan, Arbaaz Khan, Rani Mukerji, Johny ...   India
# ...                                                 ...     ...
# 8136  Shabana Azmi, Girish Karnad, Vikram, Dheeraj K...   India
# 8144  Anil Kapoor, Aishwarya Rai Bachchan, Akshaye K...   India
# 8332  Amitabh Bachchan, Zeenat Aman, Neetu Singh, Pr...   India
# 8628  Leela Naidu, Neena Gupta, Anita Kanwar, Soni R...   India
# 8629  Anil Kapoor, Shah Rukh Khan, Jackie Shroff, Sa...   India
#
#               date_added  release_year rating duration  \
# 24    September 21, 2021          1998  TV-14  166 min
# 114    September 2, 2021          1994  TV-14  143 min
# 253      August 18, 2021          1995  TV-14  135 min
# 542         July 6, 2021          1959  TV-14  143 min
# 1441     January 4, 2021          1999  TV-14  126 min
# ...                  ...           ...    ...      ...
# 8136   December 31, 2019          1977  TV-PG  123 min
# 8144       March 1, 2018          1999  TV-PG  177 min
# 8332   December 31, 2019          1979  TV-14  161 min
# 8628   December 31, 2019          1985  TV-14  134 min
# 8629       March 1, 2018          1995  TV-PG  173 min
#
#                                               listed_in  \
# 24      Comedies, International Movies, Romantic Movies
# 114             Dramas, International Movies, Thrillers
# 253       Dramas, International Movies, Romantic Movies
# 542                        Dramas, International Movies
# 1441  Action & Adventure, Comedies, International Mo...
# ...                                                 ...
# 8136   Dramas, Independent Movies, International Movies
# 8144     Dramas, International Movies, Music & Musicals
# 8332    Action & Adventure, Classic Movies, Cult Movies
# 8628               Comedies, Dramas, Independent Movies
# 8629   Action & Adventure, Dramas, International Movies
#
#                                             description
# 24    When the father of the man she loves insists t...
# 114   A wealthy industrialist’s dangerous obsession ...
# 253   Years after they elope against their family’s ...
# 542   An honest man dreams of a better life for his ...
# 1441  After receiving a heart transplant from a murd...
# ...                                                 ...
# 8136  After she enters into an arranged marriage, a ...
# 8144  Businessman Manav falls for aspiring singer Ma...
# 8332  After unwittingly using his skills to obtain m...
# 8628  A Goan native returns to his now-derelict, pal...
# 8629  After being framed, a policewoman languishing ...
#
# [81 rows x 12 columns]

# %% [markdown]
# ## selecting rows
# ### Iloc method

# %%
df.iloc[34]
# Out:
# show_id                                                       s35
# type                                                      TV Show
# title                                     Tayo and Little Wizards
# director                                                      NaN
# cast            Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# country                                                       NaN
# date_added                                     September 17, 2021
# release_year                                                 2020
# rating                                                      TV-Y7
# duration                                                 1 Season
# listed_in                                                Kids' TV
# description     Tayo speeds into an adventure when his friends...
# Name: 34, dtype: object

# %%
df.iloc[21:40]
# Out:
#    show_id     type                                         title  \
# 21     s22  TV Show                        Resurrection: Ertugrul
# 22     s23    Movie                               Avvai Shanmughi
# 23     s24    Movie  Go! Go! Cory Carson: Chrissy Takes the Wheel
# 24     s25    Movie                                         Jeans
# 25     s26  TV Show                          Love on the Spectrum
# 26     s27    Movie                                Minsara Kanavu
# 27     s28    Movie                                     Grown Ups
# 28     s29    Movie                                    Dark Skies
# 29     s30    Movie                                      Paranoia
# 30     s31    Movie                               Ankahi Kahaniya
# 31     s32  TV Show                            Chicago Party Aunt
# 32     s33  TV Show                                 Sex Education
# 33     s34  TV Show                                    Squid Game
# 34     s35  TV Show                       Tayo and Little Wizards
# 35     s36    Movie                The Father Who Moves Mountains
# 36     s37    Movie                                The Stronghold
# 37     s38  TV Show                                   Angry Birds
# 38     s39    Movie                           Birth of the Dragon
# 39     s40  TV Show                                  Chhota Bheem
#
#                                              director  \
# 21                                                NaN
# 22                                     K.S. Ravikumar
# 23                            Alex Woo, Stanley Moore
# 24                                         S. Shankar
# 25                                                NaN
# 26                                        Rajiv Menon
# 27                                       Dennis Dugan
# 28                                      Scott Stewart
# 29                                     Robert Luketic
# 30  Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket C...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                       Daniel Sandu
# 36                                     Cédric Jimenez
# 37                                                NaN
# 38                                       George Nolfi
# 39                                                NaN
#
#                                                  cast  \
# 21  Engin Altan Düzyatan, Serdar Gökhan, Hülya Dar...
# 22  Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 23  Maisie Benson, Paul Killam, Kerry Gudjohnsen, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 25                                   Brooke Satchwell
# 26  Arvind Swamy, Kajol, Prabhu Deva, Nassar, S.P....
# 27  Adam Sandler, Kevin James, Chris Rock, David S...
# 28  Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 29  Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 30  Abhishek Banerjee, Rinku Rajguru, Delzad Hiwal...
# 31  Lauren Ash, Rory O'Malley, RuPaul Charles, Jil...
# 32  Asa Butterfield, Gillian Anderson, Ncuti Gatwa...
# 33  Lee Jung-jae, Park Hae-soo, Wi Ha-jun, Oh Youn...
# 34  Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 35  Adrian Titieni, Elena Purea, Judith State, Val...
# 36  Gilles Lellouche, Karim Leklou, François Civil...
# 37  Antti Pääkkönen, Heljä Heikkinen, Lynne Guagli...
# 38  Billy Magnussen, Ron Yuan, Qu Jingjing, Terry ...
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# 39  A brave, energetic little boy with superhuman ...

# %% [markdown]
# ## Loc method

# %%
df.loc[500,"type"]
# Out:
# 'Movie'

# %% [markdown]
# ### Rename column

# %%
df.rename(columns={"title":"movie name","description":"summary","listed_in":"genre"},inplace="true")

# %%
df.iloc[100:120]
# Out:
#     show_id     type                                movie name  \
# 100    s101  TV Show                   Tobot Galaxy Detectives
# 101    s102    Movie                    Untold: Breaking Point
# 102    s103  TV Show  Countdown: Inspiration4 Mission to Space
# 103    s104    Movie                            Shadow Parties
# 104    s105  TV Show                       Tayo the Little Bus
# 105    s106    Movie                          Angamaly Diaries
# 106    s107  TV Show                                    Bunk'd
# 107    s108    Movie                          A Champion Heart
# 108    s109  TV Show                                 Dive Club
# 109    s110  TV Show                          La casa de papel
# 110    s111  TV Show         Money Heist: From Tokyo to Berlin
# 111    s112  TV Show                                  Sharkdog
# 112    s113    Movie                                     Worth
# 113    s114    Movie                    Afterlife of the Party
# 114    s115    Movie                                    Anjaam
# 115    s116    Movie                               Bright Star
# 116    s117    Movie                                    Dhanak
# 117    s118    Movie                             Final Account
# 118    s119    Movie                                   Gurgaon
# 119    s120    Movie                            Here and There
#
#                                 director  \
# 100                                  NaN
# 101             Chapman Way, Maclain Way
# 102                          Jason Hehir
# 103                           Yemi Amodu
# 104                                  NaN
# 105                 Lijo Jose Pellissery
# 106                                  NaN
# 107                         David de Vos
# 108                                  NaN
# 109                                  NaN
# 110  Luis Alfaro, Javier Gómez Santander
# 111                                  NaN
# 112                       Sara Colangelo
# 113                        Stephen Herek
# 114                         Rahul Rawail
# 115                         Jane Campion
# 116                      Nagesh Kukunoor
# 117                         Luke Holland
# 118                        Shanker Raman
# 119                             JP Habac
#
#                                                   cast  \
# 100  Austin Abell, Travis Turner, Cole Howard, Anna...
# 101                                                NaN
# 102                                                NaN
# 103  Jide Kosoko, Omotola Jalade-Ekeinde, Yemi Blaq...
# 104                         Robyn Slade, Kami Desilets
# 105  Antony Varghese, Reshma Rajan, Binny Rinky Ben...
# 106  Peyton List, Karan Brar, Skai Jackson, Miranda...
# 107  Mandy Grace, David de Vos, Donna Rusch, Devan ...
# 108  Aubri Ibrag, Sana'a Shaik, Miah Madden, Mercy ...
# 109  Úrsula Corberó, Itziar Ituño, Álvaro Morte, Pa...
# 110                                                NaN
# 111  Liam Mitchell, Dee Bradley Baker, Grey Griffin...
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 113  Victoria Justice, Midori Francis, Robyn Scott,...
# 114  Madhuri Dixit, Shah Rukh Khan, Tinnu Anand, Jo...
# 115  Abbie Cornish, Ben Whishaw, Paul Schneider, Ke...
# 116  Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...
# 117                                                NaN
# 118  Akshay Oberoi, Pankaj Tripathi, Ragini Khanna,...
# 119  Janine Gutierrez, JC Santos, Victor Anastacio,...
#
#                                country         date_added  release_year  \
# 100                                NaN  September 7, 2021          2019
# 101                      United States  September 7, 2021          2021

# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# genre                   object
# summary                 object
# dtype: object

# %%
import pandas as pd

def categorize_rating(rating):
    if pd.isna(rating):
        return "Unknown"
    
    rating = str(rating).strip()

    # Handle wrong entries like durations
    if "min" in rating:
        return "Unknown"
    
    # Kids content
    if rating in ["TV-Y", "TV-Y7", "TV-Y7-FV", "G"]:
        return "Kids"
    
    # Family / General
    elif rating in ["TV-G", "PG", "TV-PG"]:
        return "Family"
    
    # Teens
    elif rating in ["PG-13", "TV-14"]:
        return "Teen"
    
    # Adults
    elif rating in ["R", "TV-MA", "NC-17"]:
        return "Adult"
    
    # Not Rated / Others
    elif rating in ["NR", "UR"]:
        return "Unrated"
    
    else:
        return "Unrated"

# %%
df["rating_category"] = df["rating"].apply(categorize_rating)

# %%
print(df["rating_category"].value_counts())
# Out:
# rating_category
# Adult      4009
# Teen       2650
# Family     1370
# Kids        688
# Unrated      83
# Unknown       7
# Name: count, dtype: int64

# %%
df
# Out:
#      show_id     type             movie name         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 0    2021-09-25          2020  PG-13     90 min
# 1    2021-09-24          2021  TV-MA  2 Seasons
# 2    2021-09-24          2021  TV-MA   1 Season
# 3    2021-09-24          2021  TV-MA   1 Season
# 4    2021-09-24          2021  TV-MA  2 Seasons
# ...         ...           ...    ...        ...
# 8802 2019-11-20          2007      R    158 min
# 8803 2019-07-01          2018  TV-Y7  2 Seasons
# 8804 2019-11-01          2009      R     88 min
# 8805 2020-01-11          2006     PG     88 min
# 8806 2019-03-02          2015  TV-14    111 min
#
#                                                   genre  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                                 summary rating_category
# 0     As her father nears the end of his life, filmm...            Teen
# 1     After crossing paths at a party, a Cape Town t...           Adult
# 2     To protect his family from a powerful drug lor...           Adult
# 3     Feuds, flirtations and toilet talk go down amo...           Adult
# 4     In a city of coaching centers known to train I...           Adult
# ...                                                 ...             ...
# 8802  A political cartoonist, a crime reporter and a...           Adult
# 8803  While living alone in a spooky town, a young g...            Kids
# 8804  Looking to survive in a world taken over by zo...           Adult
# 8805  Dragged from civilian life, a former superhero...          Family
# 8806  A scrappy but poor boy worms his way into a ty...            Teen
#
# [8807 rows x 13 columns]

# %% [markdown]
# ## handling missing values

# %%
df.isnull()
# Out:
#       show_id   type  movie name  director   cast  country  date_added  \
# 0       False  False       False     False   True    False       False
# 1       False  False       False      True  False    False       False
# 2       False  False       False     False  False     True       False
# 3       False  False       False      True   True     True       False
# 4       False  False       False      True  False    False       False
# ...       ...    ...         ...       ...    ...      ...         ...
# 8802    False  False       False     False  False    False       False
# 8803    False  False       False      True   True     True       False
# 8804    False  False       False     False  False    False       False
# 8805    False  False       False     False  False    False       False
# 8806    False  False       False     False  False    False       False
#
#       release_year  rating  duration  genre  summary  rating_category
# 0            False   False     False  False    False            False
# 1            False   False     False  False    False            False
# 2            False   False     False  False    False            False
# 3            False   False     False  False    False            False
# 4            False   False     False  False    False            False
# ...            ...     ...       ...    ...      ...              ...
# 8802         False   False     False  False    False            False
# 8803         False   False     False  False    False            False
# 8804         False   False     False  False    False            False
# 8805         False   False     False  False    False            False
# 8806         False   False     False  False    False            False
#
# [8807 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# show_id               0
# type                  0
# movie name            0
# director           2634
# cast                825
# country             831
# date_added           10
# release_year          0
# rating                4
# duration              3
# genre                 0
# summary               0
# rating_category       0
# dtype: int64

# %% [markdown]
# ## how to fill missing values

# %%
df['director'].fillna("Unknown",inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12156\2129338133.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna("Unknown",inplace=True)

# %%
df['country'].fillna("Unknown",inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12156\3625148707.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna("Unknown",inplace=True)

# %%
df['cast'].fillna("unknown",inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12156\1670278949.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].fillna("unknown",inplace=True)

# %%
df.dropna(subset=['date_added','rating','duration'],inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# movie name         0
# director           0
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# genre              0
# summary            0
# rating_category    0
# dtype: int64

# %%
df.shape
# Out:
# (8790, 13)

# %% [markdown]
# ## handling duplicateds

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## ensuring  data cleaning

# %%
df.head()
# Out:
#   show_id     type             movie name         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                                genre  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                              summary rating_category
# 0  As her father nears the end of his life, filmm...            Teen
# 1  After crossing paths at a party, a Cape Town t...           Adult
# 2  To protect his family from a powerful drug lor...           Adult
# 3  Feuds, flirtations and toilet talk go down amo...           Adult
# 4  In a city of coaching centers known to train I...           Adult

# %%
df.tail()
# Out:
#      show_id     type   movie name         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb          Unknown
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                            unknown        Unknown
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 8802 2019-11-20          2007      R    158 min
# 8803 2019-07-01          2018  TV-Y7  2 Seasons
# 8804 2019-11-01          2009      R     88 min
# 8805 2020-01-11          2006     PG     88 min
# 8806 2019-03-02          2015  TV-14    111 min
#
#                                                genre  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                                 summary rating_category
# 8802  A political cartoonist, a crime reporter and a...           Adult
# 8803  While living alone in a spooky town, a young g...            Kids
# 8804  Looking to survive in a world taken over by zo...           Adult
# 8805  Dragged from civilian life, a former superhero...          Family
# 8806  A scrappy but poor boy worms his way into a ty...            Teen

# %%
df.shape
# Out:
# (8790, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8790 non-null   object
#  1   type             8790 non-null   object
#  2   movie name       8790 non-null   object
#  3   director         8790 non-null   object
#  4   cast             8790 non-null   object
#  5   country          8790 non-null   object
#  6   date_added       8790 non-null   datetime64[ns]
#  7   release_year     8790 non-null   int64
#  8   rating           8790 non-null   object
#  9   duration         8790 non-null   object
#  10  genre            8790 non-null   object
#  11  summary          8790 non-null   object
#  12  rating_category  8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 961.4+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'movie name', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'genre', 'summary',
#        'rating_category'],
#       dtype='object')

# %%
Movie=df[df["type"]=="Movie"]

# %%
Movie
# Out:
#      show_id   type                        movie name  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# 8802                  David Fincher
# 8804                Ruben Fleischer
# 8805                   Peter Hewitt
# 8806                    Mozez Singh
#
#                                                    cast  \
# 0                                               unknown
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added  \
# 0                                         United States 2021-09-25
# 6                                               Unknown 2021-09-24
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# ...                                                 ...        ...
# 8801                       United Arab Emirates, Jordan 2016-03-09
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 6             2021     PG   91 min
# 7             1993  TV-MA  125 min
# 9             2021  PG-13  104 min
# 12            2021  TV-MA  127 min
# ...            ...    ...      ...
# 8801          2015  TV-MA   96 min
# 8802          2007      R  158 min
# 8804          2009      R   88 min
# 8805          2006     PG   88 min
# 8806          2015  TV-14  111 min
#
#                                                  genre  \
# 0                                        Documentaries
# 6                             Children & Family Movies
# 7     Dramas, Independent Movies, International Movies
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                                 summary rating_category
# 0     As her father nears the end of his life, filmm...            Teen
# 6     Equestria's divided. But a bright-eyed hero be...          Family
# 7     On a photo shoot in Ghana, an American model s...           Adult
# 9     A woman adjusting to life after a loss contend...            Teen
# 12    After most of her family is murdered in a terr...           Adult
# ...                                                 ...             ...
# 8801  Recovering alcoholic Talal wakes up inside a s...           Adult
# 8802  A political cartoonist, a crime reporter and a...           Adult
# 8804  Looking to survive in a world taken over by zo...           Adult
# 8805  Dragged from civilian life, a former superhero...          Family
# 8806  A scrappy but poor boy worms his way into a ty...            Teen
#
# [6126 rows x 13 columns]

# %% [markdown]
# ## parase movies as numerical

# %%
Movie["duration"]=Movie["duration"].str.replace("min"," ",regex=False)
Movie["duration"]=pd.to_numeric(Movie["duration"],errors="coerce")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12156\1149245470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Movie["duration"]=Movie["duration"].str.replace("min"," ",regex=False)
# C:\Users\user\AppData\Local\Temp\ipykernel_12156\1149245470.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Movie["duration"]=pd.to_numeric(Movie["duration"],errors="coerce")

# %%
Tvshow=df[df["type"]=="TV Show"]

# %%
Tvshow
# Out:
#      show_id     type             movie name         director  \
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V          Unknown
# 8796   s8797  TV Show             Yunus Emre          Unknown
# 8797   s8798  TV Show              Zak Storm          Unknown
# 8800   s8801  TV Show     Zindagi Gulzar Hai          Unknown
# 8803   s8804  TV Show            Zombie Dumb          Unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                               unknown
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...
# ...                                                 ...
# 8795  Mike Liscio, Emily Bauer, Billy Bob Thompson, ...
# 8796  Gökhan Atalay, Payidar Tüfekçioglu, Baran Akbu...
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8803                                            unknown
#
#                                             country date_added  release_year  \
# 1                                      South Africa 2021-09-24          2021
# 2                                           Unknown 2021-09-24          2021
# 3                                           Unknown 2021-09-24          2021
# 4                                             India 2021-09-24          2021
# 5                                           Unknown 2021-09-24          2021
# ...                                             ...        ...           ...
# 8795                                  Japan, Canada 2018-05-01          2015
# 8796                                         Turkey 2017-01-17          2016
# 8797  United States, France, South Korea, Indonesia 2018-09-13          2016
# 8800                                       Pakistan 2016-12-15          2012
# 8803                                        Unknown 2019-07-01          2018
#
#      rating   duration                                              genre  \
# 1     TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2     TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3     TV-MA   1 Season                             Docuseries, Reality TV
# 4     TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
# 5     TV-MA   1 Season                 TV Dramas, TV Horror, TV Mysteries
# ...     ...        ...                                                ...
# 8795  TV-Y7  2 Seasons                             Anime Series, Kids' TV
# 8796  TV-PG  2 Seasons                  International TV Shows, TV Dramas
# 8797  TV-Y7  3 Seasons                                           Kids' TV
# 8800  TV-PG   1 Season  International TV Shows, Romantic TV Shows, TV ...
# 8803  TV-Y7  2 Seasons             Kids' TV, Korean TV Shows, TV Comedies
#
#                                                 summary rating_category
# 1     After crossing paths at a party, a Cape Town t...           Adult
# 2     To protect his family from a powerful drug lor...           Adult
# 3     Feuds, flirtations and toilet talk go down amo...           Adult
# 4     In a city of coaching centers known to train I...           Adult
# 5     The arrival of a charismatic young priest brin...           Adult
# ...                                                 ...             ...
# 8795  Now that he's discovered the Pendulum Summonin...            Kids
# 8796  During the Mongol invasions, Yunus Emre leaves...          Family
# 8797  Teen surfer Zak Storm is mysteriously transpor...            Kids
# 8800  Strong-willed, middle-class Kashaf and carefre...          Family
# 8803  While living alone in a spooky town, a young g...            Kids
#
# [2664 rows x 13 columns]

# %%
Tvshow['duration'].head(10)
# Out:
# 1     2 Seasons
# 2      1 Season
# 3      1 Season
# 4     2 Seasons
# 5      1 Season
# 8     9 Seasons
# 10     1 Season
# 11     1 Season
# 14     1 Season
# 15    4 Seasons
# Name: duration, dtype: object

# %%
Tvshow['duration'].dtype
# Out:
# dtype('O')

# %%
Tvshow['duration']=Tvshow['duration'].str.split().str[0].astype(int)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12156\1067515198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tvshow['duration']=Tvshow['duration'].str.split().str[0].astype(int)

# %%
Tvshow['duration'].dtype
# Out:
# dtype('int64')

# %%
Tvshow
# Out:
#      show_id     type             movie name         director  \
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V          Unknown
# 8796   s8797  TV Show             Yunus Emre          Unknown
# 8797   s8798  TV Show              Zak Storm          Unknown
# 8800   s8801  TV Show     Zindagi Gulzar Hai          Unknown
# 8803   s8804  TV Show            Zombie Dumb          Unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                               unknown
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...
# ...                                                 ...
# 8795  Mike Liscio, Emily Bauer, Billy Bob Thompson, ...
# 8796  Gökhan Atalay, Payidar Tüfekçioglu, Baran Akbu...
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8800  Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# 8803                                            unknown
#
#                                             country date_added  release_year  \
# 1                                      South Africa 2021-09-24          2021
# 2                                           Unknown 2021-09-24          2021
# 3                                           Unknown 2021-09-24          2021
# 4                                             India 2021-09-24          2021
# 5                                           Unknown 2021-09-24          2021
# ...                                             ...        ...           ...
# 8795                                  Japan, Canada 2018-05-01          2015
# 8796                                         Turkey 2017-01-17          2016
# 8797  United States, France, South Korea, Indonesia 2018-09-13          2016
# 8800                                       Pakistan 2016-12-15          2012
# 8803                                        Unknown 2019-07-01          2018
#
#      rating  duration                                              genre  \
# 1     TV-MA         2    International TV Shows, TV Dramas, TV Mysteries
# 2     TV-MA         1  Crime TV Shows, International TV Shows, TV Act...
# 3     TV-MA         1                             Docuseries, Reality TV
# 4     TV-MA         2  International TV Shows, Romantic TV Shows, TV ...
# 5     TV-MA         1                 TV Dramas, TV Horror, TV Mysteries
# ...     ...       ...                                                ...
# 8795  TV-Y7         2                             Anime Series, Kids' TV
# 8796  TV-PG         2                  International TV Shows, TV Dramas
# 8797  TV-Y7         3                                           Kids' TV
# 8800  TV-PG         1  International TV Shows, Romantic TV Shows, TV ...
# 8803  TV-Y7         2             Kids' TV, Korean TV Shows, TV Comedies
#
#                                                 summary rating_category
# 1     After crossing paths at a party, a Cape Town t...           Adult
# 2     To protect his family from a powerful drug lor...           Adult
# 3     Feuds, flirtations and toilet talk go down amo...           Adult
# 4     In a city of coaching centers known to train I...           Adult
# 5     The arrival of a charismatic young priest brin...           Adult
# ...                                                 ...             ...
# 8795  Now that he's discovered the Pendulum Summonin...            Kids
# 8796  During the Mongol invasions, Yunus Emre leaves...          Family
# 8797  Teen surfer Zak Storm is mysteriously transpor...            Kids
# 8800  Strong-willed, middle-class Kashaf and carefre...          Family
# 8803  While living alone in a spooky town, a young g...            Kids
#
# [2664 rows x 13 columns]

# %% [markdown]
# ## save the survivors to a new csv file

# %%
df.to_csv("netflix_cleaned.csv",index=False)

# %%
Tvshow.to_csv("netflix_Tvshows.csv",index=False)

# %%
Movie.to_csv("netflix_Movie.csv",index=False)

# %% [markdown]
# ## Load New Data

# %%
df_new=pd.read_csv("netflix_cleaned.csv")

# %%
df_new
# Out:
#      show_id     type             movie name         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8785   s8803    Movie                 Zodiac    David Fincher
# 8786   s8804  TV Show            Zombie Dumb          Unknown
# 8787   s8805    Movie             Zombieland  Ruben Fleischer
# 8788   s8806    Movie                   Zoom     Peter Hewitt
# 8789   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                               unknown        Unknown
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8785  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8786                                            unknown        Unknown
# 8787  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8788  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8789  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#       date_added  release_year rating   duration  \
# 0     2021-09-25          2020  PG-13     90 min
# 1     2021-09-24          2021  TV-MA  2 Seasons
# 2     2021-09-24          2021  TV-MA   1 Season
# 3     2021-09-24          2021  TV-MA   1 Season
# 4     2021-09-24          2021  TV-MA  2 Seasons
# ...          ...           ...    ...        ...
# 8785  2019-11-20          2007      R    158 min
# 8786  2019-07-01          2018  TV-Y7  2 Seasons
# 8787  2019-11-01          2009      R     88 min
# 8788  2020-01-11          2006     PG     88 min
# 8789  2019-03-02          2015  TV-14    111 min
#
#                                                   genre  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8785                     Cult Movies, Dramas, Thrillers
# 8786             Kids' TV, Korean TV Shows, TV Comedies
# 8787                            Comedies, Horror Movies
# 8788                 Children & Family Movies, Comedies
# 8789     Dramas, International Movies, Music & Musicals
#
#                                                 summary rating_category
# 0     As her father nears the end of his life, filmm...            Teen
# 1     After crossing paths at a party, a Cape Town t...           Adult
# 2     To protect his family from a powerful drug lor...           Adult
# 3     Feuds, flirtations and toilet talk go down amo...           Adult
# 4     In a city of coaching centers known to train I...           Adult
# ...                                                 ...             ...
# 8785  A political cartoonist, a crime reporter and a...           Adult
# 8786  While living alone in a spooky town, a young g...            Kids
# 8787  Looking to survive in a world taken over by zo...           Adult
# 8788  Dragged from civilian life, a former superhero...          Family
# 8789  A scrappy but poor boy worms his way into a ty...            Teen
#
# [8790 rows x 13 columns]

# %% [markdown]
# ## Summary Stats

# %%
df
# Out:
#      show_id     type             movie name         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                               unknown        Unknown
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                            unknown        Unknown
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 0    2021-09-25          2020  PG-13     90 min
# 1    2021-09-24          2021  TV-MA  2 Seasons
# 2    2021-09-24          2021  TV-MA   1 Season
# 3    2021-09-24          2021  TV-MA   1 Season
# 4    2021-09-24          2021  TV-MA  2 Seasons
# ...         ...           ...    ...        ...
# 8802 2019-11-20          2007      R    158 min
# 8803 2019-07-01          2018  TV-Y7  2 Seasons
# 8804 2019-11-01          2009      R     88 min
# 8805 2020-01-11          2006     PG     88 min
# 8806 2019-03-02          2015  TV-14    111 min
#
#                                                   genre  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                                 summary rating_category
# 0     As her father nears the end of his life, filmm...            Teen
# 1     After crossing paths at a party, a Cape Town t...           Adult
# 2     To protect his family from a powerful drug lor...           Adult
# 3     Feuds, flirtations and toilet talk go down amo...           Adult
# 4     In a city of coaching centers known to train I...           Adult
# ...                                                 ...             ...
# 8802  A political cartoonist, a crime reporter and a...           Adult
# 8803  While living alone in a spooky town, a young g...            Kids
# 8804  Looking to survive in a world taken over by zo...           Adult
# 8805  Dragged from civilian life, a former superhero...          Family
# 8806  A scrappy but poor boy worms his way into a ty...            Teen
#
# [8790 rows x 13 columns]

# %% [markdown]
# ### Average(Mean)

# %%
print("release_year - ",df['release_year'].mean())
# Out:
# release_year -  2014.183162684869

# %% [markdown]
# ### Mode

# %%
print("release_year - ",df['release_year'].mode())
# Out:
# release_year -  0    2018
# Name: release_year, dtype: int64

# %% [markdown]
# ### Median

# %%
print("release_year - ",df['release_year'].median())
# Out:
# release_year -  2017.0

# %% [markdown]
# ### Standard Deviation

# %%
print("release_year -",df_new["release_year"].std())
# Out:
# release_year - 8.82546602834746

# %%
df.select_dtypes(include="number").mean()
# Out:
# release_year    2014.183163
# dtype: float64

# %%
df.select_dtypes(include="number").median()
# Out:
# release_year    2017.0
# dtype: float64

# %%
df.select_dtypes(include="number").mode()
# Out:
#    release_year
# 0          2018

# %%
df.describe()
# Out:
#                           date_added  release_year
# count                           8790   8790.000000
# mean   2019-05-17 21:44:01.638225408   2014.183163
# min              2008-01-01 00:00:00   1925.000000
# 25%              2018-04-06 00:00:00   2013.000000
# 50%              2019-07-03 00:00:00   2017.000000
# 75%              2020-08-19 18:00:00   2019.000000
# max              2021-09-25 00:00:00   2021.000000
# std                              NaN      8.825466

# %% [markdown]
# - the data set contains 8790 entries
# - the average release year 2014
# - The dataset contains 8790 entries.
# - The average release year is 2014, showing that most content is fairly recent.
# - The standard deviation is 8.83, which means the data is moderatelyspread around the mean.
# - The oldest content dates back to 1925.
# - 25% of the content was released before 2013.
# - The median release year is 2017.
# - 75% of the content was released before 2019.
# - The latest content is from 2021.

# %%
df_new.describe(include='O')
# Out:
#        show_id   type            movie name director     cast        country  \
# count     8790   8790                  8790     8790     8790           8790
# unique    8790      2                  8790     4527     7679            749
# top         s1  Movie  Dick Johnson Is Dead  Unknown  unknown  United States
# freq         1   6126                     1     2621      825           2809
#
#         date_added rating  duration                         genre  \
# count         8790   8790      8790                          8790
# unique        1713     14       220                           513
# top     2020-01-01  TV-MA  1 Season  Dramas, International Movies
# freq           110   3205      1791                           362
#
#                                                   summary rating_category
# count                                                8790            8790
# unique                                               8758               5
# top     Paranormal activity at a lush, abandoned prope...           Adult
# freq                                                    4            4007

# %% [markdown]
# - total 8970 entries,means no missing values
# - 2 unique values which are movie and tv shows,dataset is heeavily movie-download
# - every titles are unique
# - 4527 unique directors,a large amount of them are unknown(2621)
# - 7679 cast are unique,a large amount of them are unknown(825)
# - most content dominated by the united states
# - 110 shows ere released on 01/01/2020
# - majority content TV-MA
# - drama and international moives are the majority of the genre
# - most target on adult audiance
# -

# %%
Movie.describe(include='O')
# Out:
#        show_id   type            movie name director     cast        country  \
# count     6126   6126                  6126     6126     6126           6126
# unique    6126      1                  6126     4353     5444            652
# top         s1  Movie  Dick Johnson Is Dead  Unknown  unknown  United States
# freq         1   6126                     1      187      475           2055
#
#        rating                         genre  \
# count    6126                          6126
# unique     14                           278
# top     TV-MA  Dramas, International Movies
# freq     2062                           362
#
#                                                   summary rating_category
# count                                                6126            6126
# unique                                               6100               5
# top     Paranormal activity at a lush, abandoned prope...           Adult
# freq                                                    4            2862

# %% [markdown]
# - total 6126 entries,means no missing
# - there is only movies in this data
# - 4353 directors are unique
# - 475 cast are unknown
# - most of the movies are dominated by the united states
# - majority content is TV-MA
# - dramas and international movies are the majority of the genre
# - 2025 movies are unique duration,152 movies are of 90 minute duration

# %%
Tvshow.describe(include='O')
# Out:
#        show_id     type     movie name director     cast        country  \
# count     2664     2664           2664     2664     2664           2664
# unique    2664        1           2664      223     2272            197
# top         s2  TV Show  Blood & Water  Unknown  unknown  United States
# freq         1     2664              1     2434      350            754
#
#        rating     genre                                            summary  \
# count    2664      2664                                               2664
# unique      9       235                                               2660
# top     TV-MA  Kids' TV  As a psychology professor faces Alzheimer's, h...
# freq     1143       219                                                  2
#
#        rating_category
# count             2664
# unique               5
# top              Adult
# freq              1145

# %% [markdown]
# ## Data Visualisation

# %% [markdown]
# ### univariate analysis
# - histogram,kde,box plot - numerical
# - count,pie - categorical
# ### bivariate analysis
# - bar plot - categorical vs numerical
# - line plot(time series) and scatter - numerical vs numerical
# ### multivariate analysis
# - heat map - correlation
# - pair plot - numerical

# %% [markdown]
# ## Histogram
# - distribution of numerical data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(4,4))
sns.histplot(data=df,x="release_year",bins=30,color="blue",kde=True)
plt.title("distribution of release year")
plt.xlabel("release year")
# Out:
# Text(0.5, 0, 'release year')

# %% [markdown]
# - the histogram shows the distribution of release year
# - majority of the releases happened in the last10-15 years
# - there are only few releases before 2000
# - the number of releases increased significantly after 2010
# - 2018 and 2019 are the years with the highest number of releases
# - the number drop suddenly after 2019
# - the distribution is strongly left skewed
# - most of the data is crowded on the right side(recent years)

# %%
plt.figure(figsize=(4,4))
sns.histplot(data=Movie,x="release_year",bins=30,color="blue",kde=True)
plt.title("distribution of release year")
plt.xlabel("release year")
# Out:
# Text(0.5, 0, 'release year')

# %% [markdown]
# - Most Content is released after 2000
# - Majority of release happened in 10-15 years
# - Releases from 1940 to 1980 are very rare
# - There is a massive spike right around 2018
# - After 2018 peak,there is a quick decline in the no.of releases in leading into 2020

# %%
plt.figure(figsize=(4,4))
sns.histplot(data=Tvshow,x="release_year",bins=30,color="blue",kde=True)
plt.title("distribution of release year")
plt.xlabel("release year")
# Out:
# Text(0.5, 0, 'release year')

# %% [markdown]
# - Almost all tv shows were released after 2010
# - TV shows from 1940 to 2000 are extremely rare
# - 2019 has the most releases followed by a small drop in 2020
# - Majority of release happened in last 5-10 years

# %% [markdown]
# ## Box Plot

# %%
plt.figure(figsize=(4,4))
sns.boxplot(data=df,x="release_year",color="blue")
plt.title("distribution of release year")
plt.xlabel("release year")
# Out:
# Text(0.5, 0, 'release year')

# %% [markdown]
# - 50% of all releases happened between approximately 2013 and 2019
# - The vertical line in the box shows the middle value is around 2017
# - The long trail of circles to the left shows that releases before 2005 are rare and considered outliers

# %% [markdown]
# ## count plot

# %%
plt.figure(figsize=(20,5))
sns.countplot(data=df,x="release_year",color="blue")
plt.title("distribution of release year")
plt.xlabel("release year")
# Out:
# Text(0.5, 0, 'release year')

# %% [markdown]
#  - Most releaes are after 2010
# - there is only very few releases before 2000
# - Release increases quickly after 2010
# - The highest releases count are in 2018–2019
# - After 2019, counts drop a bit
# - The data is right-heavy, meaning recent years dominate

# %% [markdown]
# ## Pie Chart

# %%
x=df['rating_category'].value_counts()
labels=['adult','teen','family','kids','unrated']
plt.figure(figsize=(5,4))
plt.pie(x,labels=labels,autopct="%1.1f%%",colors=["blue","green","brown","pink","yellow"])
plt.title("distribution of release year")
plt.xlabel("rating categories")
# Out:
# Text(0.5, 0, 'rating categories')

# %% [markdown]
# - This pie chart shows how many titles are in each rating group.
# - **Adult** is the biggest group, so most titles are for mature viewers.
# - **Teen** is the next biggest group.
# - **Family** and **Kids** are smaller, so child-friendly content is less common.
# - **Unrated** titles are very few.

# %% [markdown]
# ## bar plot

# %%
plt.figure(figsize=(4,4))
sns.barplot(data=Movie,x="rating_category",y="duration",color="blue")
plt.title("distribution of rating category")
plt.xlabel("rating categories")
# Out:
# Text(0.5, 0, 'rating categories')

# %% [markdown]
# - The bar plot shows average length for each rating group.
# - **Teen** and **Adult** categories have the longest durations.
# - **Kids** content is much shorter than other groups.

# %%
plt.figure(figsize=(4,4))
sns.barplot(data=Tvshow,x="rating_category",y="duration",color="blue")
plt.title("distribution of rating category")
plt.xlabel("rating categories")
# Out:
# Text(0.5, 0, 'rating categories')

# %% [markdown]
# ## line plot

# %%
plt.figure(figsize=(4,4))
sns.lineplot(data=Movie,x="release_year",y="duration",color="blue")
plt.title("distribution of release year")
plt.xlabel("rating categories")
# Out:
# Text(0.5, 0, 'rating categories')

# %% [markdown]
# - Movie lengths increased sharply from the 1940s to the mid-1960s
# - Peak average duration occurred around the 1960s
# - High variability in movie lengths during the 1960s–1980s
# - Gradual decline in duration after the 1970s
# - Modern films (2000s onward) are shorter and more consistent
# - Overall trend: rise → peak → steady decline → stabilization

# %%
plt.figure(figsize=(4,4))
sns.lineplot(data=Tvshow,x="release_year",y="duration",color="blue")
plt.title("distribution of release year")
plt.xlabel("rating categories")
# Out:
# Text(0.5, 0, 'rating categories')

# %% [markdown]
# * Values stay very low and flat until around the 1950s
# * Sharp spikes appear between the 1960s–1980s (high instability)
# * Peak occurs around the late 1970s–early 1980s
# * After 1990, values drop and fluctuate frequently
# * From 2000 onward, values stabilize at low levels
# * Overall trend: flat → volatile spikes → decline → low, stable pattern

# %% [markdown]
# ## scatter plot

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=Movie,x="release_year",y="duration")
plt.title("distribution of release year")
plt.xlabel("release_year")
# Out:
# Text(0.5, 0, 'release_year')

# %% [markdown]
# * Most movies cluster between ~80–150 minutes
# * After 2000, many more movies are released (denser points)
# * Wide spread in durations, but majority stay in mid-range
# * Some outliers: very short (<50 min) and very long (>200 min) films
# * Older films (pre-1970) are fewer but often longer
# * Overall: high variation, but typical movie length stays around ~100–140 minutes

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=Tvshow,x="release_year",y="duration")
plt.title("distribution of release year")
plt.xlabel("release_year")
# Out:
# Text(0.5, 0, 'release_year')

# %% [markdown]
# - Most TV shows cluster at low duration values, especially 1–3, so the dataset is dominated by short series.
# - The biggest concentration appears after 2010, meaning recent releases are much more common than older shows.
# - There is no clear upward trend: newer shows are not consistently longer, they remain mostly short.
# - Very long-running shows (duration above 10) are rare and appear as outliers.
# - The plot suggests Netflix content is skewed toward newer, shorter-run TV shows rather than long multi-season series.

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(6,4))
sns.heatmap(Movie.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# - The correlation between release_year and duration is -0.21.
# - This is a weak negative relationship → as release year increases, duration tends to slightly decrease.
# - The value is close to 0, so the relationship is not strong.
# - This means newer content is only slightly shorter on average, but not by much.
# - There is no strong pattern between release year and duration.

# %%
plt.figure(figsize=(6,4))
sns.heatmap(Tvshow.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# - Correlation is very weak.
# - release_year and duration are almost unrelated.
# - The value is slightly negative: about -0.082.
# - No clear trend of newer releases being longer or shorter.

# %% [markdown]
# ## Pairplot

# %%
plt.figure(figsize=(5,6))
sns.pairplot(Movie[['release_year','duration']])

# %% [markdown]
# - The pairplot shows no strong linear relationship between `release_year` and `duration`.
# - Points are scattered widely, so newer movies are not consistently longer or shorter.
# - Most movies cluster around typical durations, regardless of release year.
# - The trend is almost flat, confirming the weak negative correlation.

# %%
plt.figure(figsimnghhze=(5,6))
sns.pairplot(Tvshow[['release_year','duration']])

# %% [markdown]
# - most releases are from 2010 onward.
# - Peak release activity is around 2018–2019.
# -  TV shows are fewer and mostly short-run.
# - Ratings are skewed toward adult content, with teen content second-largest.
# - TV show durations are mostly 1–3 seasons; long series are rare.
# - Release year vs duration shows only a weak negative correlation.

# %% [markdown]
# ## Conclusion
# In this project, the Netflix Dataset was successfully cleaned and analyzed. Several changes were made to improve the quality of the data. Missing values in columns like director, cast, and country were handled by filling or removing them.The movies and tv shows are seperated to a file. The duration column was cleaned and converted into a proper numeric format, where movies are shown in minutes and TV shows in seasons.
#
# After cleaning, the dataset became more accurate and easy to use for analysis. The analysis showed that Netflix has more movies than TV shows, most content is released after 2010, and popular genres include drama and comedy. It also showed that content is mainly made for young and adult audiences.
#
# Overall, this project helped in understanding how to clean data, fix errors, and perform data analysis. It shows the importance of data preprocessing before doing any analysis.

# %% [markdown]
# ## Key Insights

# %% [markdown]
# - Movies dominated in netflix than tv shows.
# - In the dataset 6126 Movies and 2664 Tv shows are  there.
# - Most content dominated by United States.
# - Most of the movies and tv shows target on adult audience.
# - After cleaning the dataset ,have 8790 entries.
# - The average release year is 2014.
# - The median release year is 2017.
# - The standard deviation of release year is 8.825.
# - Most of the directors are unknown.
# - Most of the cast are unknown.
# - Most of genre are drama & international movies.
# - A huge majority of the releases happened in the last 10-15 years.
# - The no.of releases started growing very fast after 2010.
# - After 2018 peak,there is a quick decline in the no.of releases in leading into 2020.
# - long trail of circles to the left shows that releases before 2005 are rare and considered outliers.
# - The highest releases count are in 2018-2019.
# - Adult is biggest rating category,so most titles are mature viewers.
# - Teen and adult categories have the longest durations.
# - Kids content is much shorter than other group.
# - Movie length increased sharply from the 1940's to the mid 1960's.
# - Some outliers very short (<50 min) and very long (>200 min) films.
# - The correlation between release year and duration is -0.21.
# - The value is close to 0,so the relationship is not strong
# - No strong linear relationship between release year and duration
# - Tv show duration are mostly 1-3 seasons
